# %% [markdown]
# ### Hands-on Lab: Build an Interactive Dashboard with Ploty Dash
# Rather than using the provided theiadocker instance that does not persist data, I am adapting the assignment to be run on jupyter notebook, original assignment instructions here: https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/lab_theia_plotly_dash.md.html - brt-h

# %%
# !pip install dash
# !pip install dash==1.19.0
# !pip install jupyter_dash
# !pip install --upgrade plotly
# Out:
# Requirement already satisfied: dash in c:\users\kettromeo\anaconda3\lib\site-packages (1.19.0)
# Requirement already satisfied: plotly in c:\users\kettromeo\anaconda3\lib\site-packages (from dash) (5.22.0)
# Requirement already satisfied: future in c:\users\kettromeo\anaconda3\lib\site-packages (from dash) (0.18.2)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\kettromeo\anaconda3\lib\site-packages (from dash) (1.15.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\kettromeo\anaconda3\lib\site-packages (from dash) (1.1.2)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\kettromeo\anaconda3\lib\site-packages (from dash) (4.11.2)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\kettromeo\anaconda3\lib\site-packages (from dash) (1.9.0)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\kettromeo\anaconda3\lib\site-packages (from dash) (1.1.2)
# Requirement already satisfied: flask-compress in c:\users\kettromeo\anaconda3\lib\site-packages (from dash) (1.15)
# Requirement already satisfied: packaging in c:\users\kettromeo\anaconda3\lib\site-packages (from plotly->dash) (23.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\kettromeo\anaconda3\lib\site-packages (from plotly->dash) (8.3.0)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\kettromeo\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (1.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\kettromeo\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (2.11.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\kettromeo\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (1.1.0)
# Requirement already satisfied: click>=5.1 in c:\users\kettromeo\anaconda3\lib\site-packages (from Flask>=1.0.4->dash) (7.1.2)
# Requirement already satisfied: zstandard; platform_python_implementation != "PyPy" in c:\users\kettromeo\anaconda3\lib\site-packages (from flask-compress->dash) (0.22.0)
# Requirement already satisfied: brotli; platform_python_implementation != "PyPy" in c:\users\kettromeo\anaconda3\lib\site-packages (from flask-compress->dash) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\kettromeo\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash) (1.1.1)
# Requirement already satisfied: dash==1.19.0 in c:\users\kettromeo\anaconda3\lib\site-packages (1.19.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\kettromeo\anaconda3\lib\site-packages (from dash==1.19.0) (1.1.2)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\kettromeo\anaconda3\lib\site-packages (from dash==1.19.0) (1.1.2)
# Requirement already satisfied: future in c:\users\kettromeo\anaconda3\lib\site-packages (from dash==1.19.0) (0.18.2)
# Requirement already satisfied: plotly in c:\users\kettromeo\anaconda3\lib\site-packages (from dash==1.19.0) (5.22.0)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\kettromeo\anaconda3\lib\site-packages (from dash==1.19.0) (1.15.0)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\kettromeo\anaconda3\lib\site-packages (from dash==1.19.0) (1.9.0)
# Requirement already satisfied: flask-compress in c:\users\kettromeo\anaconda3\lib\site-packages (from dash==1.19.0) (1.15)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\kettromeo\anaconda3\lib\site-packages (from dash==1.19.0) (4.11.2)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\kettromeo\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.11.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\kettromeo\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (1.1.0)
# Requirement already satisfied: click>=5.1 in c:\users\kettromeo\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (7.1.2)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\kettromeo\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (1.0.1)
# Requirement already satisfied: packaging in c:\users\kettromeo\anaconda3\lib\site-packages (from plotly->dash==1.19.0) (23.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\kettromeo\anaconda3\lib\site-packages (from plotly->dash==1.19.0) (8.3.0)
# Requirement already satisfied: zstandard; platform_python_implementation != "PyPy" in c:\users\kettromeo\anaconda3\lib\site-packages (from flask-compress->dash==1.19.0) (0.22.0)
# Requirement already satisfied: brotli; platform_python_implementation != "PyPy" in c:\users\kettromeo\anaconda3\lib\site-packages (from flask-compress->dash==1.19.0) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\kettromeo\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash==1.19.0) (1.1.1)
# Requirement already satisfied: jupyter_dash in c:\users\kettromeo\anaconda3\lib\site-packages (0.4.2)
# Requirement already satisfied: ansi2html in c:\users\kettromeo\anaconda3\lib\site-packages (from jupyter_dash) (1.9.1)
# Requirement already satisfied: flask in c:\users\kettromeo\anaconda3\lib\site-packages (from jupyter_dash) (1.1.2)
# Requirement already satisfied: ipython in c:\users\kettromeo\anaconda3\lib\site-packages (from jupyter_dash) (7.19.0)
# Requirement already satisfied: ipykernel in c:\users\kettromeo\anaconda3\lib\site-packages (from jupyter_dash) (5.3.4)
# Requirement already satisfied: retrying in c:\users\kettromeo\anaconda3\lib\site-packages (from jupyter_dash) (1.3.4)
# Requirement already satisfied: requests in c:\users\kettromeo\anaconda3\lib\site-packages (from jupyter_dash) (2.24.0)
# Requirement already satisfied: nest-asyncio in c:\users\kettromeo\anaconda3\lib\site-packages (from jupyter_dash) (1.4.2)
# Requirement already satisfied: dash in c:\users\kettromeo\anaconda3\lib\site-packages (from jupyter_dash) (1.19.0)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\kettromeo\anaconda3\lib\site-packages (from flask->jupyter_dash) (1.0.1)
# Requirement already satisfied: click>=5.1 in c:\users\kettromeo\anaconda3\lib\site-packages (from flask->jupyter_dash) (7.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\kettromeo\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.11.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\kettromeo\anaconda3\lib\site-packages (from flask->jupyter_dash) (1.1.0)
# Requirement already satisfied: pygments in c:\users\kettromeo\anaconda3\lib\site-packages (from ipython->jupyter_dash) (2.7.2)
# Requirement already satisfied: traitlets>=4.2 in c:\users\kettromeo\anaconda3\lib\site-packages (from ipython->jupyter_dash) (5.0.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\kettromeo\anaconda3\lib\site-packages (from ipython->jupyter_dash) (50.3.1.post20201107)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\kettromeo\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.4.4)
# Requirement already satisfied: decorator in c:\users\kettromeo\anaconda3\lib\site-packages (from ipython->jupyter_dash) (4.4.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\kettromeo\anaconda3\lib\site-packages (from ipython->jupyter_dash) (3.0.8)
# Requirement already satisfied: jedi>=0.10 in c:\users\kettromeo\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.17.1)
# Requirement already satisfied: pickleshare in c:\users\kettromeo\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: backcall in c:\users\kettromeo\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: jupyter-client in c:\users\kettromeo\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1.7)
# Requirement already satisfied: tornado>=4.2 in c:\users\kettromeo\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.0.4)
# Requirement already satisfied: six>=1.7.0 in c:\users\kettromeo\anaconda3\lib\site-packages (from retrying->jupyter_dash) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\kettromeo\anaconda3\lib\site-packages (from requests->jupyter_dash) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\kettromeo\anaconda3\lib\site-packages (from requests->jupyter_dash) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kettromeo\anaconda3\lib\site-packages (from requests->jupyter_dash) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\kettromeo\anaconda3\lib\site-packages (from requests->jupyter_dash) (1.25.11)
# Requirement already satisfied: flask-compress in c:\users\kettromeo\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.15)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\kettromeo\anaconda3\lib\site-packages (from dash->jupyter_dash) (4.11.2)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\kettromeo\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.15.0)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\kettromeo\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.1.2)
# Requirement already satisfied: future in c:\users\kettromeo\anaconda3\lib\site-packages (from dash->jupyter_dash) (0.18.2)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\kettromeo\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.9.0)
# Requirement already satisfied: plotly in c:\users\kettromeo\anaconda3\lib\site-packages (from dash->jupyter_dash) (5.22.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\kettromeo\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask->jupyter_dash) (1.1.1)
# Requirement already satisfied: ipython-genutils in c:\users\kettromeo\anaconda3\lib\site-packages (from traitlets>=4.2->ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: wcwidth in c:\users\kettromeo\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\kettromeo\anaconda3\lib\site-packages (from jedi>=0.10->ipython->jupyter_dash) (0.7.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\kettromeo\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (2.8.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\kettromeo\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (19.0.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\kettromeo\anaconda3\lib\site-packages (from jupyter-client->ipykernel->jupyter_dash) (4.6.3)
# Requirement already satisfied: brotli; platform_python_implementation != "PyPy" in c:\users\kettromeo\anaconda3\lib\site-packages (from flask-compress->dash->jupyter_dash) (1.1.0)
# Requirement already satisfied: zstandard; platform_python_implementation != "PyPy" in c:\users\kettromeo\anaconda3\lib\site-packages (from flask-compress->dash->jupyter_dash) (0.22.0)
# Requirement already satisfied: packaging in c:\users\kettromeo\anaconda3\lib\site-packages (from plotly->dash->jupyter_dash) (23.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\kettromeo\anaconda3\lib\site-packages (from plotly->dash->jupyter_dash) (8.3.0)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\kettromeo\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel->jupyter_dash) (227)
# Requirement already up-to-date: plotly in c:\users\kettromeo\anaconda3\lib\site-packages (5.22.0)
# Requirement already satisfied, skipping upgrade: tenacity>=6.2.0 in c:\users\kettromeo\anaconda3\lib\site-packages (from plotly) (8.3.0)
# Requirement already satisfied, skipping upgrade: packaging in c:\users\kettromeo\anaconda3\lib\site-packages (from plotly) (23.1)

# %%
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
from jupyter_dash import JupyterDash
import plotly.graph_objects as go

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# -atplotlib                         3.3.2
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.10.0
# anaconda-project                   0.8.3
# ansi2html                          1.9.1
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asn1crypto                         1.4.0
# astroid                            2.4.2
# astropy                            4.0.2
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              20.3.0
# autopep8                           1.5.4
# Babel                              2.8.1
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.1
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# bcrypt                             3.2.0
# beautifulsoup4                     4.9.3
# bitarray                           1.6.1
# bkcharts                           0.2
# bleach                             3.2.1
# bokeh                              2.2.3
# boto                               2.49.0
# Bottleneck                         1.3.2
# Brotli                             1.1.0
# brotlipy                           0.7.0
# certifi                            2020.6.20
# cffi                               1.14.3
# chardet                            3.0.4
# charset-normalizer                 3.3.2
# click                              7.1.2
# cloudpickle                        1.6.0
# clyent                             1.2.2
# colorama                           0.4.4
# comtypes                           1.1.7
# conda                              4.9.2
# conda-build                        3.20.5
# conda-package-handling             1.7.2
# conda-verify                       3.4.2
# contextlib2                        0.6.0.post1
# contourpy                          1.1.1
# cryptography                       41.0.5
# cssselect                          1.2.0
# cycler                             0.10.0
# Cython                             0.29.21
# cytoolz                            0.11.0
# dash                               1.19.0
# dash-core-components               1.15.0
# dash-html-components               1.1.2
# dash-renderer                      1.9.0
# dash-table                         4.11.2
# dask                               2.30.0
# decorator                          4.4.2
# defusedxml                         0.6.0
# diff-match-patch                   20200713
# distributed                        2.30.1
# distro                             1.8.0
# docutils                           0.16
# entrypoints                        0.3
# et-xmlfile                         1.0.1
# fastcache                          1.1.0
# filelock                           3.0.12
# flake8                             3.8.4
# Flask                              1.1.2
# Flask-Compress                     1.15
# fonttools                          4.42.1
# fsspec                             0.8.3
# future                             0.18.2
# gevent                             20.9.0
# glob2                              0.7
# greenlet                           0.4.17
# h5py                               2.10.0
# HeapDict                           1.0.1
# html5lib                           1.1
# idna                               2.10
# imageio                            2.9.0
# imagesize                          1.2.0
# imbalanced-learn                   0.11.0
# imblearn                           0.0
# importlib-metadata                 2.0.0
# importlib-resources                6.1.0
# iniconfig                          1.1.1
# intervaltree                       3.1.0
# ipykernel                          5.3.4
# ipython                            7.19.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.5.1
# isort                              5.6.4
# itsdangerous                       1.1.0
# jdcal                              1.4.1
# jedi                               0.17.1
# Jinja2                             2.11.2
# joblib                             1.3.2
# JPype1                             1.4.1
# json5                              0.9.5
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.7
# jupyter-console                    6.2.0
# jupyter-core                       4.6.3
# jupyter-dash                       0.4.2
# jupyterlab                         2.2.6
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  1.2.0
# keyring                            21.4.0
# kiwisolver                         1.3.0
# lazy-object-proxy                  1.4.3
# libarchive-c                       2.9
# llvmlite                           0.34.0
# locket                             0.2.0
# lxml                               4.6.1
# MarkupSafe                         1.1.1
# matplotlib                         3.7.3
# mccabe                             0.6.1
# menuinst                           1.4.16
# mistune                            0.8.4
# mkl-fft                            1.2.0
# mkl-random                         1.1.1
# mkl-service                        2.3.0
# mock                               4.0.2
# more-itertools                     8.6.0
# mpmath                             1.1.0
# msgpack                            1.0.0
# multipledispatch                   0.6.0
# navigator-updater                  0.2.1
# nbclient                           0.5.1
# nbconvert                          6.0.7
# nbformat                           5.0.8
# nest-asyncio                       1.4.2
# networkx                           2.5
# nltk                               3.5
# nose                               1.3.7
# notebook                           6.1.4
# numba                              0.51.2
# numexpr                            2.7.1
# numpy                              1.23.5
# numpydoc                           1.1.0
# olefile                            0.46
# openpyxl                           3.0.5
# packaging                          23.1
# pandas                             1.1.3
# pandocfilters                      1.4.3
# paramiko                           2.7.2
# parso                              0.7.0
# partd                              1.1.0
# path                               15.0.0
# pathlib2                           2.3.5
# pathtools                          0.1.2
# patsy                              0.5.3
# pdfminer.six                       20221105
# pdfplumber                         0.10.3
# pdfquery                           0.4.3
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             10.1.0
# pip                                20.2.4
# pkginfo                            1.6.1
# plotly                             5.22.0
# pluggy                             0.13.1
# ply                                3.11
# prometheus-client                  0.8.0
# prompt-toolkit                     3.0.8
# psutil                             5.7.2
# py                                 1.9.0
# pycodestyle                        2.6.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycurl                             7.43.0.6
# pydocstyle                         5.1.1
# pyflakes                           2.2.0
# Pygments                           2.7.2
# pylint                             2.6.0
# PyNaCl                             1.4.0
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          19.1.0
# pyparsing                          2.4.7
# pypdf                              3.17.1
# pypdfium2                          4.24.0
# pyquery                            2.0.0
# pyreadline                         2.1
# pyrsistent                         0.17.3
# PySocks                            1.7.1
# pytest                             0.0.0
# python-dateutil                    2.8.1
# python-jsonrpc-server              0.4.0
# python-language-server             0.35.1
# pytz                               2020.1
# PyWavelets                         1.1.1
# pywin32                            227
# pywin32-ctypes                     0.2.0
# pywinpty                           0.5.7
# PyYAML                             5.3.1
# pyzmq                              19.0.2
# QDarkStyle                         2.8.1
# QtAwesome                          1.0.1
# qtconsole                          4.7.7
# QtPy                               1.9.0
# regex                              2020.10.15
# requests                           2.24.0
# retrying                           1.3.4
# roman                              4.1
# rope                               0.18.0
# Rtree                              0.9.4
# ruamel-yaml                        0.15.87
# scikit-image                       0.17.2
# scikit-learn                       1.3.2
# scipy                              1.10.1
# seaborn                            0.11.0
# Send2Trash                         1.5.0
# setuptools                         50.3.1.post20201107
# simplegeneric                      0.8.1
# singledispatch                     3.4.0.3
# sip                                4.19.13
# six                                1.15.0
# snowballstemmer                    2.0.0
# sortedcollections                  1.2.1
# sortedcontainers                   2.2.2
# soupsieve                          2.0.1
# Sphinx                             3.2.1
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             1.0.3
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.4
# sphinxcontrib-websupport           1.2.4
# spyder                             4.1.5
# spyder-kernels                     1.9.4
# SQLAlchemy                         1.3.20
# statsmodels                        0.14.0
# sympy                              1.6.2
# tables                             3.6.1
# tabula-py                          2.8.2
# tabulate                           0.9.0
# tblib                              1.7.0
# tenacity                           8.3.0
# terminado                          0.9.1
# testpath                           0.4.4
# threadpoolctl                      3.1.0
# tifffile                           2020.10.1
# toml                               0.10.1
# toolz                              0.11.1
# tornado                            6.0.4
# tqdm                               4.50.2
# traitlets                          5.0.5
# typing-extensions                  4.12.0
# ujson                              4.0.1
# unicodecsv                         0.14.1
# urllib3                            1.25.11
# watchdog                           0.10.3
# waterfallcharts                    3.8
# wcwidth                            0.2.5
# webencodings                       0.5.1
# Werkzeug                           1.0.1
# wheel                              0.35.1
# widgetsnbextension                 3.5.1
# win-inet-pton                      1.1.0
# win-unicode-console                0.5
# wincertstore                       0.2
# wrapt                              1.11.2
# xgboost                            2.0.0
# xlrd                               1.2.0
# XlsxWriter                         1.3.7
# xlwings                            0.20.8
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yapf                               0.30.0
# yellowbrick                        1.5
# zict                               2.0.0
# zipp                               3.4.0
# zope.event                         4.5.0
# zope.interface                     5.1.2
# zstandard                          0.22.0

# %%
# !jupyter labextension list
# Out:
# JupyterLab v2.2.6
# Known labextensions:
#
# Build recommended, please run `jupyter lab build`:
#     jupyterlab-dash needs to be included in build
#    app dir: C:\Users\Kettromeo\anaconda3\share\jupyter\lab
#         jupyterlab-dash v0.4.2 enabled  ok

# %%
spacex_df = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv')

# %%
# skeleton Dash app to be completed in this lab, downloaded from:
# https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/spacex_dash_app.py
# redundant lines commented out

# Import required libraries
# import pandas as pd
# import dash
# import dash_html_components as html
# import dash_core_components as dcc
# from dash.dependencies import Input, Output
import plotly.express as px

# Read the airline data into pandas dataframe
# spacex_df = pd.read_csv("spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
# app = dash.Dash(__name__) # commented out as we are using JupyterDash instead of dash.Dash
app = JupyterDash(__name__)

# Create an app layout
app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),
                                # TASK 1: Add a dropdown list to enable Launch Site selection
                                # The default select value is for ALL sites
                                # dcc.Dropdown(id='site-dropdown',...)
                                dcc.Dropdown(id='site-dropdown',
                                             options=[
                                                     {'label': 'All Sites', 'value': 'ALL'},
                                                     {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
                                                     {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
                                                     {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
                                                     {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'}
                                                     ],
                                             value='ALL',
                                             placeholder='Select a Launch Site here',
                                             searchable=True
                                             # style={'width':'80%','padding':'3px','font-size':'20px','text-align-last':'center'}
                                             ),
                                html.Br(),

                                # TASK 2: Add a pie chart to show the total successful launches count for all sites
                                # If a specific launch site was selected, show the Success vs. Failed counts for the site
                                html.Div(dcc.Graph(id='success-pie-chart')),
                                html.Br(),

                                html.P("Payload range (Kg):"),
                                # TASK 3: Add a slider to select payload range
                                #dcc.RangeSlider(id='payload-slider',...)
                                dcc.RangeSlider(id='payload-slider',
                                                min=0,
                                                max=10000,
                                                step=1000,
                                                value=[min_payload, max_payload]
                                                ),

                                # TASK 4: Add a scatter chart to show the correlation between payload and launch success
                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),
                                ])

# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output
@app.callback(Output(component_id='success-pie-chart', component_property='figure'),
              Input(component_id='site-dropdown', component_property='value'))
def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(filtered_df, values='class', 
        names='Launch Site', 
        title='Success Count for all launch sites')
        return fig
    else:
        # return the outcomes piechart for a selected site
        filtered_df=spacex_df[spacex_df['Launch Site']== entered_site]
        filtered_df=filtered_df.groupby(['Launch Site','class']).size().reset_index(name='class count')
        fig=px.pie(filtered_df,values='class count',names='class',title=f"Total Success Launches for site {entered_site}")
        return fig

# TASK 4:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output
@app.callback(Output(component_id='success-payload-scatter-chart',component_property='figure'),
                [Input(component_id='site-dropdown',component_property='value'),
                Input(component_id='payload-slider',component_property='value')])
def scatter(entered_site,payload):
    filtered_df = spacex_df[spacex_df['Payload Mass (kg)'].between(payload[0],payload[1])]
    # thought reusing filtered_df may cause issues, but tried it out of curiosity and it seems to be working fine
    
    if entered_site=='ALL':
        fig=px.scatter(filtered_df,x='Payload Mass (kg)',y='class',color='Booster Version Category',title='Success count on Payload mass for all sites')
        return fig
    else:
        fig=px.scatter(filtered_df[filtered_df['Launch Site']==entered_site],x='Payload Mass (kg)',y='class',color='Booster Version Category',title=f"Success count on Payload mass for site {entered_site}")
        return fig

# Run the app
if __name__ == '__main__':
    app.run_server(mode='inline', host='localhost')
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://localhost:8050/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
